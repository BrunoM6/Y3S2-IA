# %% [markdown]
# # Fraud detection in online sales
# We have a large dataset pertaining to online e-commerce sales, labeled as fraudulent and non-fraudulent, and our objective is to develop a machine learning solution to classify future sales based on a set of information parameters given.

# %% [markdown]
# ## Viewing of Data
# Initially, we want to observe the shape of data, frequence of the classification feature, so that we can see if we need to fill-in/exclude any data, or take any other preprocessing steps to maintain a balanced approach without over-representation, over-fitting or misleading data.

# %%
import pandas as pd

# load dataset
dataset = pd.read_csv('dataset/merged_dataset.csv')

# shape, types and example
print("Dataset Shape:", dataset.shape)
print("\nData Types:\n", dataset.dtypes)
print("\nFirst Rows:\n", dataset.head())

# categorical feature distribution
print("\nTransaction Fraudulence Data Distribution:\n", dataset['Is.Fraudulent'].value_counts())
print("\nSource Data Distribution:\n", dataset['source'].value_counts())
print("\nBrowser Data Distribution:\n", dataset['browser'].value_counts())
print("\nSex Data Distribution:\n", dataset['sex'].value_counts())
print("\nPayment Method Data Distribution:\n", dataset['Payment.Method'].value_counts())
print("\nProduct Category Data Distribution:\n", dataset['Product.Category'].value_counts())
print("\nDevice Used Data Distribution:\n", dataset['Device.Used'].value_counts())
print("\nAddress Match Distribution:\n", dataset['Address.Match'].value_counts())
# Out:
# Dataset Shape: (300000, 14)
#
# Data Types:
#  Transaction.Date       object
# Transaction.Amount    float64
# Customer.Age            int64
# Is.Fraudulent           int64
# Account.Age.Days        int64
# Transaction.Hour        int64
# source                 object
# browser                object
# sex                    object
# Payment.Method         object
# Product.Category       object
# Quantity                int64
# Device.Used            object
# Address.Match           int64
# dtype: object
#
# First Rows:
#        Transaction.Date  Transaction.Amount  Customer.Age  Is.Fraudulent  \
# 0  2024-02-12 10:05:21              145.98            29              0
# 1  2024-01-25 22:24:06              677.62            40              0
# 2  2024-03-26 20:32:44              798.63            40              0
# 3  2024-01-07 23:14:51              314.65            34              0
# 4  2024-01-19 11:01:19              119.80            11              1
#
#    Account.Age.Days  Transaction.Hour  source  browser sex Payment.Method  \
# 0               172                10     Ads       IE   F    credit card
# 1               250                22  Direct  FireFox   M    credit card
# 2               118                20     Ads   Chrome   M         PayPal
# 3               187                23     SEO       IE   M  bank transfer
# 4                 5                11  Direct   Safari   M         PayPal
#
#   Product.Category  Quantity Device.Used  Address.Match
# 0    home & garden         3      mobile              1
# 1         clothing         3     desktop              1
# 2         clothing         3      mobile              1
# 3     toys & games         3     desktop              1
# 4     toys & games         3      tablet              1
#
# Transaction Fraudulence Data Distribution:
#  Is.Fraudulent
# 0    278397
# 1     21603
# Name: count, dtype: int64
#
# Source Data Distribution:
#  source
# SEO       120361
# Ads       118890
# Direct     60749
# Name: count, dtype: int64
#
# Browser Data Distribution:
#  browser
# Chrome     121531
# IE          73282
# Safari      49068
# FireFox     48781
# Opera        7338
# Name: count, dtype: int64
#
# Sex Data Distribution:
#  sex
# M    162484
# F    137516
# Name: count, dtype: int64
#
# Payment Method Data Distribution:
#  Payment.Method
# credit card      75273
# debit card       75068
# bank transfer    74854
# PayPal           74805
# Name: count, dtype: int64
#
# Product Category Data Distribution:
#  Product.Category
# health & beauty    60337
# electronics        60173
# toys & games       59915
# clothing           59909
# home & garden      59666
# Name: count, dtype: int64
#
# Device Used Data Distribution:
#  Device.Used
# desktop    100070
# mobile     100035
# tablet      99895
# Name: count, dtype: int64
#
# Address Match Distribution:
#  Address.Match
# 1    269719
# 0     30281
# Name: count, dtype: int64

# %% [markdown]
# ### Conclusions on Viewing
# We have a large dataset, with 300000 individual labeled cases, with 13 features, mixed numeric and categoric, which means we will need to encode categorical variables before modeling. <br>
# We also have a 13 to 1 distribution of non-fraudulent vs fraudulent cases, which means a highly imbalaced dataset, meaning accuracy will be a misleading metric, and precision, recall and f1-score will be more expressive of the model's peformance. <br>
# We might need techniques for handling imbalance, like oversampling, undersampling or class weighting in algorithms. <br>
# As for the distributions of categorical data, the source, sex, payment method, product category and device used all follow pretty uniform distributions. While browser and address match over-represent Chrome and 1 respectively.

# %% [markdown]
# ## Feature Preprocessing
# Simple checking (valid values and not-null) and processing of multiple features and cleaning up of the data into a new file. We are clearly shaping our data into a desired state of values. <br>
# We also maintain label encoding on Is.Fraudulent, sex and address match because it suits the format and meaning of these categories. <br>
# We perform one-hot encoding on source, browser, Payment.Method, Product.Category and Device.Used, in order to not express false order, at the cost of increasing the number of features. <br>
# We finally process the raw date into numeric parts fed as numbers into the model.

# %%
import pandas as pd

def validate_row(row):
    errors = []

    try:
        pd.to_datetime(row['Transaction.Date'])
    except Exception:
        errors.append('Invalid Transaction.Date')

    if not isinstance(row['Transaction.Amount'], (int, float)) or row['Transaction.Amount'] < 0:
        errors.append('Invalid Transaction.Amount')
    

    if row['Is.Fraudulent'] not in [0, 1]:
        errors.append('Invalid Is.Fraudulent')

    if not isinstance(row['Account.Age.Days'], (int, float)) or not (row['Account.Age.Days'] <= 0 or row['Account.Age.Days'] <= 365):
        errors.appned('Invalid Account.Age.Days')
    
    if not isinstance(row['Transaction.Hour'], (int, float)) or not (0 <= row['Transaction.Hour'] <= 23):
        errors.append('Invalid Transaction.Hour')
    
    if row['source'] not in ['Ads', 'SEO', 'Direct']:
        errors.append('Invalid source')
    
    if row['browser'] not in ['Chrome', 'Safari', 'IE', 'FireFox', 'Opera']:
        errors.append('Invalid source')

    if row['sex'] not in ['M', 'F']:
        errors.append('Invalid sex')

    if row['Payment.Method'] not in ['credit card', 'debit card', 'PayPal', 'bank transfer']:
        errors.append('Invalid Payment.Method')

    if row['Product.Category'] not in ['clothing', 'health & beauty', 'home & garden', 'electronics', 'toys & games']:
        errors.append('Invalid Product.Category')

    if not isinstance(row['Quantity'], (int, float)) or not (1 <= row['Quantity'] <= 5):
        errors.append('Invalid Quantity')

    if row['Device.Used'] not in ['mobile', 'desktop', 'tablet']:
        errors.append('Invalid Device.Used')

    if row['Address.Match'] not in [0, 1]:
        errors.append('Invalid Address.Match')

    return errors

# apply validate_row to all rows
validation_results = dataset.apply(validate_row, axis=1)

# filter into only errors
invalid_rows = dataset[validation_results.apply(lambda x: len(x) > 0)]
error_messages = validation_results[validation_results.apply(lambda x: len(x) > 0)]

# show errors
for (row, errors) in zip(invalid_rows.iterrows(), error_messages):
    index, data = row
    print(f"Row {index} has errors: {errors}")

# %%
import pandas as pd 
import numpy as np

# machine learning tool
from sklearn.preprocessing import LabelEncoder

# remove invalid rows
valid_dataset = dataset[validation_results.apply(lambda x: len(x) == 0)].copy()

# label encode 'sex' category
le_sex = LabelEncoder()
valid_dataset['sex'] = le_sex.fit_transform(valid_dataset['sex'])

# select one hot columns
one_hot_columns = ['source', 'browser', 'Payment.Method', 'Product.Category', 'Device.Used']

# perform automatic one-hot encoding through get_dummies
valid_dataset = pd.get_dummies(valid_dataset, columns=one_hot_columns)


# extract transaction date values 
valid_dataset['Transaction.Date'] = pd.to_datetime(valid_dataset['Transaction.Date'], format='mixed')

# create columns for date
valid_dataset['Transaction.Year'] = valid_dataset['Transaction.Date'].dt.year
valid_dataset['Transaction.Month'] = valid_dataset['Transaction.Date'].dt.month
valid_dataset['Transaction.Day'] = valid_dataset['Transaction.Date'].dt.day
valid_dataset['Transaction.Weekday'] = valid_dataset['Transaction.Date'].dt.weekday
# valid_dataset['Transaction.Hour'] = valid_dataset['Transaction.Hour'] # already exists

# perform cyclic enconding so that model understands weekday/hour proximity (e.g. 23 is close to 0)
# for days of week (0-6)
valid_dataset['Weekday_Sin'] = np.sin(2 * np.pi * valid_dataset['Transaction.Weekday'] / 7)
valid_dataset['Weekday_Cos'] = np.cos(2 * np.pi * valid_dataset['Transaction.Weekday'] / 7)

# for hour of day (0-23)
valid_dataset['Hour_Sin'] = np.sin(2 * np.pi * valid_dataset['Transaction.Hour'] / 24)
valid_dataset['Hour_Cos'] = np.cos(2 * np.pi * valid_dataset['Transaction.Hour'] / 24)

# drop redundant column
valid_dataset = valid_dataset.drop(columns=['Transaction.Date'])

# One-hot encode the Transaction.Weekday
valid_dataset = pd.get_dummies(valid_dataset, columns=['Transaction.Weekday'])

# save the prepared
valid_dataset.to_csv('dataset/prepared_dataset.csv', index=False)

# %% [markdown]
# ## Prepare Data
# Now we prepare the data for the model. We split up fraudulence from other characteristics, perform the train/test split, our objective is 80/10/10, as in training/validating/testing, so we use 0.1 test size to extract the 10% for testing. <br>
# X represents the data, and y the associated labels.

# %%
import pandas as pd
import random

# import machine learning tool
from sklearn.model_selection import train_test_split

dataset = pd.read_csv('dataset/prepared_dataset.csv')

# extract label and features from data
X = dataset.drop('Is.Fraudulent', axis=1)
y = dataset['Is.Fraudulent']

# perform train test split based on random number and keep balance of fraud cases in split
random_number = random.randint(0, 2147483647)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, 
    test_size=0.1, 
    random_state=random_number,
    stratify=y # maintain balanced split
)

# %% [markdown]
# # Random Forest
# Next, we create a RandomForestClassifier model and a pipeline to reach the best ammount of n_estimators and best class weight. <br>
# For scoring, we could use f1 if we want to catch as many fraudulent cases as possible while maintaining high precision. <br>
# We shouldn't use accuracy here, because we have an imbalanced dataset and want to catch as many fraudulent cases as possible, not maximize overall accuracy since it can make our model too conservative, or precision, because the few false positives optimization that precision intrinsically does makes it miss more fraudulent cases in exchange for few false positives. <br>
# We should choose recall because typically in these types of problems, actually catching all the fraud cases and performing manual filtering of the non-fraud cases tends to be the most useful solution. <br>
# In order to maintain a 80/10/10 split, we perform cross validation with 9 partitions to split up the testing/validation data into 10% chunks. <br>
# We experiment with a large parameter grid and perform random search on hyperparameter configurations to find a good combination which yields the "best" estimator (within the search space of the iterations).

# %%
import random
import numpy as np

# import model and pipeline tools
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold
from sklearn.pipeline import Pipeline
from sklearn.metrics import recall_score, precision_score, classification_report, precision_recall_curve

# create the pipeline, classifier model of RandomForest
random_number = random.randint(0, 2147483647)
pipeline = Pipeline([
    ('classifier', RandomForestClassifier(random_state=random_number))
])

# define hyperparameter search space
param_grid = {
    'classifier__n_estimators': [100, 200, 300],
    'classifier__max_depth': [None, 10, 20, 30],
    'classifier__min_samples_split': [2, 5, 10],
    'classifier__min_samples_leaf': [1, 2, 4],
    'classifier__max_features': ['sqrt', 'log2'],       # drop 'auto'
    'classifier__bootstrap': [True],                     # only bootstrap=True
    'classifier__class_weight': ['balanced', None],      # no balanced_subsample
}


# define multiple scorings to be compared
scoring = {
  'accuracy' : 'accuracy', 
  'precision' : 'precision', 
  'recall' : 'recall', # maximizes fraud detection
  'f1' : 'f1', # balance between precision and recall -> can optimize to be good
  'roc_auc' : 'roc_auc' # separation of classes
}

random_search = RandomizedSearchCV(
    pipeline,
    param_grid,
    n_iter=40,
    cv=StratifiedKFold(n_splits=9, shuffle=True, random_state=random_number),
    scoring=scoring, # check for all relevant scorings
    refit='f1', # balance between recall -> get more fraud cases and precision
    verbose=3, # actually get information per fold
    n_jobs=-1 # use all CPU cores
)

random_search.fit(X_train, y_train)

# best parameters
print("\nBest Hyperparameters:")
print(random_search.best_params_)

# best estimator 
best_model = random_search.best_estimator_
y_proba = best_model.predict_proba(X_test)[:, 1]

# test thresholds
thresholds = np.linspace(0.1, 0.9, 81)
recalls = []
precisions = []

# compute precision, recall, and the thresholds
precision, recall, thresh = precision_recall_curve(y_test, y_proba)

# compute F1 at each threshold
f1_scores = 2 * (precision * recall) / (precision + recall + 1e-12)

# find the index of the maximum F1
best_idx = np.nanargmax(f1_scores)
best_thresh = thresh[best_idx]

print(f"Best threshold (max F1): {best_thresh:.3f},  F1 = {f1_scores[best_idx]:.3f}")

# apply it
y_pred = (y_proba >= best_thresh).astype(int)
print(classification_report(y_test, y_pred))
# Out:
# Fitting 9 folds for each of 40 candidates, totalling 360 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 48
#      29 scoring = {
#      30   'accuracy' : 'accuracy',
#      31   'precision' : 'precision',
#    (...)     34   'roc_auc' : 'roc_auc' # separation of classes
#      35 }
#      37 random_search = RandomizedSearchCV(
#      38     pipeline,
#      39     param_grid,
#    (...)     45     n_jobs=-1 # use all CPU cores
#      46 )
# ---> 48 random_search.fit(X_train, y_train)
#      50 # best parameters
#      51 print("\nBest Hyperparameters:")
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/sklearn/base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1024, in BaseSearchCV.fit(self, X, y, **params)
#    1018     results = self._format_results(
#    1019         all_candidate_params, n_splits, all_out, all_more_results
#    1020     )
#    1022     return results
# -> 1024 self._run_search(evaluate_candidates)
#    1026 # multimetric is determined here because in the case of a callable
#    1027 # self.scoring the return type is only known after calling
#    1028 first_test_score = all_out[0]["test_scores"]
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/sklearn/model_selection/_search.py:1951, in RandomizedSearchCV._run_search(self, evaluate_candidates)
#    1949 def _run_search(self, evaluate_candidates):
#    1950     """Search n_iter candidates from param_distributions"""
# -> 1951     evaluate_candidates(
#    1952         ParameterSampler(
#    1953             self.param_distributions, self.n_iter, random_state=self.random_state
#    1954         )
#    1955     )
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/sklearn/model_selection/_search.py:970, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     962 if self.verbose > 0:
#     963     print(
#     964         "Fitting {0} folds for each of {1} candidates,"
#     965         " totalling {2} fits".format(
#     966             n_splits, n_candidates, n_candidates * n_splits
#     967         )
#     968     )
# --> 970 out = parallel(
#     971     delayed(_fit_and_score)(
#     972         clone(base_estimator),
#     973         X,
#     974         y,
#     975         train=train,
#     976         test=test,
#     977         parameters=parameters,
#     978         split_progress=(split_idx, n_splits),
#     979         candidate_progress=(cand_idx, n_candidates),
#     980         **fit_and_score_kwargs,
#     981     )
#     982     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     983         enumerate(candidate_params),
#     984         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#     985     )
#     986 )
#     988 if len(out) < 1:
#     989     raise ValueError(
#     990         "No fits were performed. "
#     991         "Was the CV iterator empty? "
#     992         "Were there no candidates?"
#     993     )
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/sklearn/utils/parallel.py:77, in Parallel.__call__(self, iterable)
#      72 config = get_config()
#      73 iterable_with_config = (
#      74     (_with_config(delayed_func, config), args, kwargs)
#      75     for delayed_func, args, kwargs in iterable
#      76 )
# ---> 77 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/joblib/parallel.py:2071, in Parallel.__call__(self, iterable)
#    2065 # The first item from the output is blank, but it makes the interpreter
#    2066 # progress until it enters the Try/Except block of the generator and
#    2067 # reaches the first `yield` statement. This starts the asynchronous
#    2068 # dispatch of the tasks to the workers.
#    2069 next(output)
# -> 2071 return output if self.return_generator else list(output)
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/joblib/parallel.py:1681, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1678     yield
#    1680     with self._backend.retrieval_context():
# -> 1681         yield from self._retrieve()
#    1683 except GeneratorExit:
#    1684     # The generator has been garbage collected before being fully
#    1685     # consumed. This aborts the remaining tasks if possible and warn
#    1686     # the user if necessary.
#    1687     self._exception = True
#
# File ~/miniconda3/envs/IA/lib/python3.13/site-packages/joblib/parallel.py:1799, in Parallel._retrieve(self)
#    1788 if self.return_ordered:
#    1789     # Case ordered: wait for completion (or error) of the next job
#    1790     # that have been dispatched and not retrieved yet. If no job
#    (...)   1794     # control only have to be done on the amount of time the next
#    1795     # dispatched job is pending.
#    1796     if (nb_jobs == 0) or (
#    1797         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1798     ):
# -> 1799         time.sleep(0.01)
#    1800         continue
#    1802 elif nb_jobs == 0:
#    1803     # Case unordered: jobs are added to the list of jobs to
#    1804     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1810     # timeouts before any other dispatched job has completed and
#    1811     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysis (Random Forest)
# Our binary classification model has an overall very high precision for the majority class, and a lower one for the minority class, since we are prioritizing recall over precision to catch the largest ammount of fraud cases. <br>
# The recall for 0 is also much bigger, reflecting the class imbalance. <br>
# The f1-score indicates that the mix between precision and recall is very good for the 0 label and mediocre for the 1 label. <br>
# The dataset is heavily unbalanced, with a lot more legitimate than fraudulent cases, which makes it so that the model becomes better at identifying 0 cases than 1 cases, which is evident from the Classification Report. This iteration of the model is great at guaranteeing lack of fraud, but at identifying fraud it is not so good, only reaching less than half the cases.

# %% [markdown]
# ## AUC and Confusion Matrix
# We use the ROC-Curve and a Confusion Matrix to better visualize these results and the four possible predictions done (FN, TN, FP and TP).

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, RocCurveDisplay
import matplotlib.pyplot as plt

# AUC score and ROC Curve
# for this we need predicted probabilities for class 1
y_proba = best_model.predict_proba(X_test)[:, 1] 

auc_score = roc_auc_score(y_test, y_proba)
print(f"AUC Score: {auc_score:.2f}")

RocCurveDisplay.from_predictions(y_test, y_proba)
plt.title("ROC Curve")
plt.show()

# confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
# plot optimal threshold chosen
# Out:
# AUC Score: 0.80

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Obter resultados da grelha
results = pd.DataFrame(random_search.cv_results_)

# Selecionar colunas relevantes
cols = ['param_classifier__class_weight', 'mean_test_recall', 'mean_test_f1', 'mean_test_roc_auc']
summary = results[cols].groupby('param_classifier__class_weight').mean().reset_index()

# Mostrar resultados ordenados por recall
print(summary.sort_values(by='mean_test_recall', ascending=False))
# Out:
#   param_classifier__class_weight  mean_test_recall  mean_test_f1  \
# 1             balanced_subsample          0.380650      0.548580
# 0                       balanced          0.378747      0.546688
#
#    mean_test_roc_auc
# 1           0.795491
# 0           0.794620
# [CV 8/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.564) recall: (test=0.396) roc_auc: (test=0.799) total time= 2.7min
# [CV 9/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.551) recall: (test=0.383) roc_auc: (test=0.800) total time= 2.7min
# [CV 4/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.544) recall: (test=0.375) roc_auc: (test=0.792) total time= 2.7min
# [CV 5/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.537) recall: (test=0.371) roc_auc: (test=0.801) total time= 2.8min
# [CV 2/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.554) recall: (test=0.384) roc_auc: (test=0.799) total time= 2.8min
# [CV 7/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.538) recall: (test=0.371) roc_auc: (test=0.783) total time= 2.8min
# [CV 3/9] END classifier__class_weight=balanced, classifier__n_estimators=200; f1: (test=0.533) recall: (test=0.367) roc_auc: (test=0.778) total time= 2.8min
# [CV 5/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.535) recall: (test=0.369) roc_auc: (test=0.797) total time= 2.8min
# [CV 7/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.541) recall: (test=0.373) roc_auc: (test=0.782) total time= 2.8min
# [CV 3/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.538) recall: (test=0.371) roc_auc: (test=0.783) total time= 2.8min
# [CV 6/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.552) recall: (test=0.384) roc_auc: (test=0.808) total time= 2.8min
# [CV 4/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.548) recall: (test=0.380) roc_auc: (test=0.793) total time= 2.8min
# [CV 2/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.554) recall: (test=0.385) roc_auc: (test=0.799) total time= 2.8min
# [CV 1/9] END classifier__class_weight=balanced_subsample, classifier__n_estimators=200; f1: (test=0.549) recall: (test=0.381) roc_auc: (test=0.798) total time= 2.8min

# %%
# Logistics Regression

# %% [markdown]
# # Neural Network (MLP - Multi Layer Perceptron)

# %%
import random

# import model and pipeline tools
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import recall_score, precision_score, classification_report

# create the pipeline, classifier model of MLPClassifier
random_number = random.randint(0, 2147483647)
pipeline = Pipeline([
    ('scaler', StandardScabler()),
    ('classifier', MLPClassifier(random_state=random_number))
])

# define hyperparameter search space
param_grid = {
    'classifier__hidden_layer_sizes': [50,100,200],
    'classifier__activation': ['logistic', 'relu'],
    'classifier__solver': ['adam','sgd'],
    'classifier__alpha':[0.0001,0.001],
    'classifier__learning_rate':['constant','adaptive'],
    'classifier__learning_rate_init':[0.001,0.005,0.01],
    'classifier__max_iter':[500,1000]
}

# define multiple scorings to be compared
scoring = {
  'recall' : 'recall', # maximizes fraud detection
  'f1' : 'f1', # balance between precision and recall
  'roc_auc' : 'roc_auc' # separation of classes
}

grid_search = GridSearchCV(
    pipeline,
    param_grid,
    cv=9, # 9-fold cv
    scoring=scoring, # check for all relevant scorings
    refit='recall', # use recall
    verbose=3, # actually get information per fold
    n_jobs=-1 # use all CPU cores
)

grid_search.fit(X_train, y_train)

# best parameters
print("\nBest Hyperparameters:")
print(grid_search.best_params_)

# best estimator 
best_model = grid_search.best_estimator_
y_proba = best_model.predict_proba(X_test)[:, 1]

# test thresholds
thresholds = np.linspace(0.1, 0.9, 81)
recalls = []
precisions = []

for t in thresholds:
    y_pred_thresh = (y_proba >= t).astype(int)
    recalls.append(recall_score(y_test, y_pred_thresh))
    precisions.append(precision_score(y_test, y_pred_thresh, zero_division=0))

# best estimator 
best_model = grid_search.best_estimator_

# find threshold with maximum recall
best_idx = np.argmax(recalls)
best_threshold = thresholds[best_idx]

y_pred = (y_proba >= best_threshold).astype(int)

print("\nClassification Report for Best Model:")
print(classification_report(y_test, y_pred))
# Out:
# Fitting 9 folds for each of 288 candidates, totalling 2592 fits
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.561) recall: (test=0.406) roc_auc: (test=0.801) total time= 1.3min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.110) recall: (test=0.058) roc_auc: (test=0.750) total time=  30.1s
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.116) recall: (test=0.062) roc_auc: (test=0.775) total time=  29.4s
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.544) recall: (test=0.387) roc_auc: (test=0.795) total time= 2.0min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.555) recall: (test=0.396) roc_auc: (test=0.797) total time= 1.9min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.404) roc_auc: (test=0.807) total time=  57.1s
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.550) recall: (test=0.396) roc_auc: (test=0.793) total time= 1.4min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.108) recall: (test=0.057) roc_auc: (test=0.758) total time= 1.4min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.588) recall: (test=0.433) roc_auc: (test=0.811) total time= 1.4min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.561) recall: (test=0.408) roc_auc: (test=0.804) total time= 1.2min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.794) total time= 1.1min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.541) recall: (test=0.385) roc_auc: (test=0.794) total time= 2.9min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.404) roc_auc: (test=0.807) total time=  53.9s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.553) recall: (test=0.398) roc_auc: (test=0.804) total time=  51.0s
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.558) recall: (test=0.399) roc_auc: (test=0.804) total time= 2.5min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.130) recall: (test=0.070) roc_auc: (test=0.771) total time=  48.8s
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.548) recall: (test=0.401) roc_auc: (test=0.776) total time= 3.8min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.165) recall: (test=0.091) roc_auc: (test=0.748) total time=  29.0s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.170) recall: (test=0.094) roc_auc: (test=0.766) total time=  30.6s
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.169) recall: (test=0.093) roc_auc: (test=0.757) total time=  29.4s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.170) recall: (test=0.094) roc_auc: (test=0.766) total time=  28.9s
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.570) recall: (test=0.419) roc_auc: (test=0.798) total time= 1.7min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.560) recall: (test=0.414) roc_auc: (test=0.788) total time= 1.5min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.537) recall: (test=0.382) roc_auc: (test=0.797) total time= 2.6min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.548) recall: (test=0.407) roc_auc: (test=0.789) total time= 3.8min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.136) recall: (test=0.074) roc_auc: (test=0.764) total time= 2.2min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.556) recall: (test=0.406) roc_auc: (test=0.801) total time= 1.8min[CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.563) recall: (test=0.406) roc_auc: (test=0.794) total time= 1.5min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.100) recall: (test=0.053) roc_auc: (test=0.767) total time=  30.6s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.561) recall: (test=0.403) roc_auc: (test=0.805) total time= 2.0min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.555) recall: (test=0.402) roc_auc: (test=0.798) total time=  56.9s
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.553) recall: (test=0.402) roc_auc: (test=0.795) total time=  41.2s
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.539) recall: (test=0.381) roc_auc: (test=0.796) total time= 1.2min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.586) recall: (test=0.439) roc_auc: (test=0.816) total time=  52.0s
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.561) recall: (test=0.406) roc_auc: (test=0.801) total time= 1.4min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.552) recall: (test=0.400) roc_auc: (test=0.793) total time= 1.3min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.103) recall: (test=0.055) roc_auc: (test=0.768) total time= 1.4min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.552) recall: (test=0.397) roc_auc: (test=0.799) total time= 3.1min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.553) recall: (test=0.402) roc_auc: (test=0.795) total time=  41.4s
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.586) recall: (test=0.439) roc_auc: (test=0.816) total time=  51.2s
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.589) recall: (test=0.430) roc_auc: (test=0.816) total time= 2.4min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.559) recall: (test=0.407) roc_auc: (test=0.786) total time= 3.9min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.130) recall: (test=0.070) roc_auc: (test=0.771) total time=  47.8s
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.157) recall: (test=0.086) roc_auc: (test=0.775) total time=  48.0s
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.566) recall: (test=0.410) roc_auc: (test=0.788) total time= 2.2min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.165) recall: (test=0.091) roc_auc: (test=0.748) total time=  30.9s
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.164) recall: (test=0.090) roc_auc: (test=0.773) total time=  30.0s
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.405) roc_auc: (test=0.793) total time= 1.2min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.556) recall: (test=0.398) roc_auc: (test=0.806) total time= 2.6min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.553) recall: (test=0.408) roc_auc: (test=0.782) total time= 3.1min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.141) recall: (test=0.077) roc_auc: (test=0.768) total time= 2.2min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.133) recall: (test=0.072) roc_auc: (test=0.770) total time= 2.1min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.551) recall: (test=0.401) roc_auc: (test=0.790) total time= 2.3min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.542) recall: (test=0.389) roc_auc: (test=0.783) total time= 1.8min[CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.542) recall: (test=0.387) roc_auc: (test=0.788) total time= 1.4min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.109) recall: (test=0.058) roc_auc: (test=0.770) total time=  32.6s
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.794) total time= 1.2min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.797) total time= 1.2min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.552) recall: (test=0.397) roc_auc: (test=0.800) total time= 2.0min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.553) recall: (test=0.402) roc_auc: (test=0.795) total time=  40.0s
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.539) recall: (test=0.381) roc_auc: (test=0.796) total time= 1.2min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.555) recall: (test=0.404) roc_auc: (test=0.800) total time=  59.4s
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.567) recall: (test=0.407) roc_auc: (test=0.802) total time= 1.3min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.568) recall: (test=0.419) roc_auc: (test=0.801) total time= 1.2min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.541) recall: (test=0.385) roc_auc: (test=0.794) total time= 3.0min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.544) recall: (test=0.390) roc_auc: (test=0.790) total time=  40.8s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.553) recall: (test=0.398) roc_auc: (test=0.804) total time=  53.4s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.553) recall: (test=0.398) roc_auc: (test=0.802) total time= 2.6min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.557) recall: (test=0.406) roc_auc: (test=0.792) total time= 4.1min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.144) recall: (test=0.078) roc_auc: (test=0.759) total time=  48.0s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.566) recall: (test=0.413) roc_auc: (test=0.802) total time= 1.8min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.169) recall: (test=0.093) roc_auc: (test=0.757) total time=  29.4s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.566) recall: (test=0.413) roc_auc: (test=0.802) total time= 1.7min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.555) recall: (test=0.407) roc_auc: (test=0.802) total time= 1.4min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.570) recall: (test=0.419) roc_auc: (test=0.798) total time= 1.7min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.562) recall: (test=0.403) roc_auc: (test=0.808) total time= 2.4min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.129) recall: (test=0.069) roc_auc: (test=0.758) total time= 2.2min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.548) recall: (test=0.401) roc_auc: (test=0.776) total time= 4.0min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.585) recall: (test=0.434) roc_auc: (test=0.810) total time= 2.3min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.549) recall: (test=0.402) roc_auc: (test=0.789) total time= 1.8min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.551) recall: (test=0.395) roc_auc: (test=0.793) total time= 1.6min[CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.588) recall: (test=0.433) roc_auc: (test=0.811) total time= 1.4min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.110) recall: (test=0.058) roc_auc: (test=0.765) total time=  32.3s
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.561) recall: (test=0.408) roc_auc: (test=0.804) total time= 1.2min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.794) total time= 1.1min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.555) recall: (test=0.398) roc_auc: (test=0.800) total time= 2.0min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.567) recall: (test=0.418) roc_auc: (test=0.798) total time=  58.2s
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.561) recall: (test=0.402) roc_auc: (test=0.809) total time= 1.2min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.118) recall: (test=0.063) roc_auc: (test=0.750) total time= 1.3min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.561) recall: (test=0.406) roc_auc: (test=0.801) total time= 1.2min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.794) total time= 1.1min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.552) recall: (test=0.400) roc_auc: (test=0.792) total time= 1.1min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.535) recall: (test=0.378) roc_auc: (test=0.795) total time= 2.9min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.558) recall: (test=0.399) roc_auc: (test=0.804) total time= 2.4min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.566) recall: (test=0.415) roc_auc: (test=0.792) total time= 4.0min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.131) recall: (test=0.070) roc_auc: (test=0.758) total time=  48.0s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.150) recall: (test=0.082) roc_auc: (test=0.769) total time=  47.9s
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.405) roc_auc: (test=0.801) total time= 2.5min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.178) recall: (test=0.099) roc_auc: (test=0.763) total time=  28.8s
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.551) recall: (test=0.395) roc_auc: (test=0.793) total time= 1.5min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.590) recall: (test=0.433) roc_auc: (test=0.818) total time= 2.4min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.548) recall: (test=0.401) roc_auc: (test=0.776) total time= 3.9min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.565) recall: (test=0.415) roc_auc: (test=0.796) total time= 4.1min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.566) recall: (test=0.410) roc_auc: (test=0.788) total time= 2.2min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.562) recall: (test=0.405) roc_auc: (test=0.801) total time= 2.5min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.405) roc_auc: (test=0.793) total time= 1.2min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.536) recall: (test=0.381) roc_auc: (test=0.787) total time= 1.5min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.555) recall: (test=0.407) roc_auc: (test=0.802) total time= 1.4min[CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.552) recall: (test=0.400) roc_auc: (test=0.793) total time= 1.2min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.099) recall: (test=0.052) roc_auc: (test=0.758) total time=  31.5s
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.103) recall: (test=0.055) roc_auc: (test=0.769) total time=  30.4s
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.541) recall: (test=0.385) roc_auc: (test=0.793) total time= 1.8min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.561) recall: (test=0.403) roc_auc: (test=0.805) total time= 1.9min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.548) recall: (test=0.391) roc_auc: (test=0.794) total time= 1.5min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.552) recall: (test=0.398) roc_auc: (test=0.802) total time= 1.5min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.113) recall: (test=0.060) roc_auc: (test=0.764) total time= 1.4min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.114) recall: (test=0.061) roc_auc: (test=0.759) total time= 1.3min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.535) recall: (test=0.378) roc_auc: (test=0.795) total time= 2.7min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.555) recall: (test=0.397) roc_auc: (test=0.801) total time= 3.0min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.567) recall: (test=0.413) roc_auc: (test=0.807) total time= 1.1min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.589) recall: (test=0.430) roc_auc: (test=0.816) total time= 2.6min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.136) recall: (test=0.074) roc_auc: (test=0.765) total time=  46.0s
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.559) recall: (test=0.407) roc_auc: (test=0.786) total time= 3.7min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.135) recall: (test=0.073) roc_auc: (test=0.757) total time=  29.2s
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.156) recall: (test=0.086) roc_auc: (test=0.765) total time=  31.2s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.135) recall: (test=0.073) roc_auc: (test=0.757) total time=  32.1s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.561) recall: (test=0.404) roc_auc: (test=0.805) total time= 1.8min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.536) recall: (test=0.381) roc_auc: (test=0.787) total time= 1.6min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.555) recall: (test=0.407) roc_auc: (test=0.802) total time= 1.4min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.559) recall: (test=0.407) roc_auc: (test=0.786) total time= 3.6min
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.553) recall: (test=0.408) roc_auc: (test=0.782) total time= 3.0min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.142) recall: (test=0.077) roc_auc: (test=0.775) total time= 2.1min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.166) recall: (test=0.092) roc_auc: (test=0.774) total time= 2.1min
# [CV 7/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.150) recall: (test=0.082) roc_auc: (test=0.766) total time= 2.1min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.550) recall: (test=0.392) roc_auc: (test=0.800) total time= 4.3min[CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.099) recall: (test=0.052) roc_auc: (test=0.758) total time=  32.9s
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.545) recall: (test=0.391) roc_auc: (test=0.793) total time= 1.2min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.568) recall: (test=0.419) roc_auc: (test=0.801) total time= 1.2min
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.568) recall: (test=0.419) roc_auc: (test=0.801) total time= 1.1min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.544) recall: (test=0.387) roc_auc: (test=0.795) total time= 2.1min
# [CV 2/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.544) recall: (test=0.390) roc_auc: (test=0.790) total time=  38.8s
# [CV 1/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.563) recall: (test=0.406) roc_auc: (test=0.811) total time= 1.4min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.588) recall: (test=0.433) roc_auc: (test=0.811) total time= 1.6min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.555) recall: (test=0.404) roc_auc: (test=0.800) total time=  59.2s
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.562) recall: (test=0.406) roc_auc: (test=0.797) total time= 1.2min
# [CV 3/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.550) recall: (test=0.398) roc_auc: (test=0.794) total time= 1.0min
# [CV 9/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.590) recall: (test=0.438) roc_auc: (test=0.805) total time= 1.2min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.552) recall: (test=0.397) roc_auc: (test=0.799) total time= 3.0min
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.567) recall: (test=0.418) roc_auc: (test=0.798) total time=  57.5s
# [CV 6/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=50, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.560) recall: (test=0.401) roc_auc: (test=0.798) total time= 2.6min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.144) recall: (test=0.078) roc_auc: (test=0.759) total time=  50.0s
# [CV 4/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.553) recall: (test=0.408) roc_auc: (test=0.782) total time= 3.1min
# [CV 8/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.549) recall: (test=0.402) roc_auc: (test=0.789) total time= 1.8min
# [CV 5/9] END classifier__activation=logistic, classifier__alpha=0.0001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.176) recall: (test=0.097) roc_auc: (test=0.758) total time=  28.9s
# ...
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.547) recall: (test=0.407) roc_auc: (test=0.777) total time= 7.2min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.558) recall: (test=0.405) roc_auc: (test=0.797) total time= 7.3min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.555) recall: (test=0.400) roc_auc: (test=0.805) total time= 7.2min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.542) recall: (test=0.387) roc_auc: (test=0.789) total time= 2.6min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.586) recall: (test=0.427) roc_auc: (test=0.813) total time= 3.4min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.559) recall: (test=0.412) roc_auc: (test=0.780) total time=16.1min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.531) recall: (test=0.388) roc_auc: (test=0.774) total time=10.6min
#
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.546) recall: (test=0.389) roc_auc: (test=0.793) total time= 3.3min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.541) recall: (test=0.392) roc_auc: (test=0.776) total time=12.2min
# [CV 8/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.552) recall: (test=0.408) roc_auc: (test=0.782) total time=15.7min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.560) recall: (test=0.412) roc_auc: (test=0.779) total time= 6.6min
#
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.560) recall: (test=0.415) roc_auc: (test=0.778) total time=10.4min
#
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.549) recall: (test=0.389) roc_auc: (test=0.804) total time= 1.5min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.560) recall: (test=0.412) roc_auc: (test=0.779) total time=11.8min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.581) recall: (test=0.437) roc_auc: (test=0.790) total time= 4.7min
#
# [CV 4/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.546) recall: (test=0.393) roc_auc: (test=0.799) total time= 2.5min
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.540) recall: (test=0.387) roc_auc: (test=0.789) total time= 2.4min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.558) recall: (test=0.399) roc_auc: (test=0.801) total time= 1.2min
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.567) recall: (test=0.407) roc_auc: (test=0.809) total time= 1.2min
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.567) recall: (test=0.411) roc_auc: (test=0.806) total time= 1.6min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.560) recall: (test=0.404) roc_auc: (test=0.792) total time= 2.9min
# [CV 4/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.554) recall: (test=0.407) roc_auc: (test=0.788) total time= 2.6min
# [CV 1/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.566) recall: (test=0.412) roc_auc: (test=0.798) total time= 2.6min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.586) recall: (test=0.432) roc_auc: (test=0.809) total time= 2.4min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.558) recall: (test=0.399) roc_auc: (test=0.801) total time= 1.2min
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.566) recall: (test=0.408) roc_auc: (test=0.805) total time= 3.3min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.587) recall: (test=0.431) roc_auc: (test=0.818) total time= 4.2min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=100, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.565) recall: (test=0.409) roc_auc: (test=0.793) total time= 4.7min
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.541) recall: (test=0.391) roc_auc: (test=0.788) total time= 4.4min
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.559) recall: (test=0.415) roc_auc: (test=0.786) total time= 6.3min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.542) recall: (test=0.387) roc_auc: (test=0.789) total time= 2.6min
# [CV 8/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.549) recall: (test=0.404) roc_auc: (test=0.779) total time=13.0min
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.544) recall: (test=0.405) roc_auc: (test=0.768) total time=10.8min
# [CV 4/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.543) recall: (test=0.399) roc_auc: (test=0.780) total time= 4.9min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.581) recall: (test=0.434) roc_auc: (test=0.797) total time= 5.8min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.557) recall: (test=0.409) roc_auc: (test=0.783) total time= 6.5min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.559) recall: (test=0.401) roc_auc: (test=0.797) total time= 3.1min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.566) recall: (test=0.414) roc_auc: (test=0.784) total time=11.5min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.578) recall: (test=0.436) roc_auc: (test=0.794) total time=17.0min
# [CV 8/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.553) recall: (test=0.413) roc_auc: (test=0.782) total time= 5.6min
#
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.583) recall: (test=0.433) roc_auc: (test=0.811) total time= 4.5min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.575) recall: (test=0.446) roc_auc: (test=0.797) total time=13.6min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.559) recall: (test=0.410) roc_auc: (test=0.780) total time= 8.6min
# [CV 8/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=constant, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.546) recall: (test=0.404) roc_auc: (test=0.779) total time= 8.8min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.001, classifier__max_iter=1000, classifier__solver=adam; f1: (test=0.545) recall: (test=0.397) roc_auc: (test=0.773) total time= 9.4min
# [CV 5/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.564) recall: (test=0.402) roc_auc: (test=0.801) total time= 2.6min
# [CV 3/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.005, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.549) recall: (test=0.400) roc_auc: (test=0.774) total time=12.8min
# [CV 1/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.557) recall: (test=0.397) roc_auc: (test=0.808) total time= 1.8min
# [CV 2/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.535) recall: (test=0.377) roc_auc: (test=0.794) total time= 1.9min
# [CV 6/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=adam; f1: (test=0.555) recall: (test=0.394) roc_auc: (test=0.801) total time= 2.3min
# [CV 9/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=500, classifier__solver=sgd; f1: (test=0.581) recall: (test=0.437) roc_auc: (test=0.790) total time=10.3min
# [CV 7/9] END classifier__activation=relu, classifier__alpha=0.001, classifier__hidden_layer_sizes=200, classifier__learning_rate=adaptive, classifier__learning_rate_init=0.01, classifier__max_iter=1000, classifier__solver=sgd; f1: (test=0.555) recall: (test=0.411) roc_auc: (test=0.781) total time= 6.1min

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_auc_score, RocCurveDisplay
import matplotlib.pyplot as plt

# AUC score and ROC Curve
# for this we need predicted probabilities for class 1
y_proba = best_model.predict_proba(X_test)[:, 1] 

auc_score = roc_auc_score(y_test, y_proba)
print(f"AUC Score: {auc_score:.2f}")

RocCurveDisplay.from_predictions(y_test, y_proba)
plt.title("ROC Curve")
plt.show()

# confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model.classes_)
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
# Out:
# AUC Score: 0.78

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Obter resultados da grelha
results = pd.DataFrame(grid_search.cv_results_)

# Selecionar colunas relevantes
cols = ['param_classifier__activation', 'mean_test_recall', 'mean_test_f1', 'mean_test_roc_auc']
summary = results[cols].groupby('param_classifier__activation').mean().reset_index()

# Mostrar resultados ordenados por recall
print(summary.sort_values(by='mean_test_recall', ascending=False))
# Out:
#   param_classifier__activation  mean_test_recall  mean_test_f1  \
# 1                         relu          0.403781      0.556783
# 0                     logistic          0.301546      0.427600
#
#    mean_test_roc_auc
# 1           0.796103
# 0           0.787095
